# %%
vimport pandas as pd

# Load the dataset
df = pd.read_excel('std_marks_sheet.xlsx')

# Display first few rows to understand columns
print("Dataset Preview:")
print(df.head())
print("\nColumn names:", df.columns.tolist())

# Assuming columns: Name, Roll_Num, Python, NumPy, Pandas, Streamlit, ML, DL, NLP, Total, Grade
# Adjust column names as per your actual file

# 1. Display all students who scored more than 75 in Python
q1 = df[df['Python'] > 75]
print("\n1. Students with Python > 75:", q1[['Name', 'Python']])

# 2. Show records of students whose Grade is A
q2 = df[df['Grade'] == 'A']
print("\n2. Students with Grade A:", q2)

# 3. Find students who scored less than 60 in NumPy
q3 = df[df['NumPy'] < 60]
print("\n3. Students with NumPy < 60:", q3[['Name', 'NumPy']])

# 4. Display students with Total marks greater than 450
q4 = df[df['Total'] > 450]
print("\n4. Students with Total > 450:", q4[['Name', 'Total']])

# 5. Show only name and roll num of students who scored above 80 in Pandas
q5 = df[df['Pandas'] > 80][['Name', 'Roll_Num']]
print("\n5. Students with Pandas > 80 (Name, Roll_Num):", q5)

# 6. Filter students whose Streamlit marks are between 60 and 80
q6 = df[(df['Streamlit'] >= 60) & (df['Streamlit'] <= 80)]
print("\n6. Students with Streamlit between 60-80:", q6[['Name', 'Streamlit']])

# 7. Display students who scored exactly 90 in ML
q7 = df[df['ML'] == 90]
print("\n7. Students with ML = 90:", q7[['Name', 'ML']])

# 8. Find students whose DL marks are less than 50
q8 = df[df['DL'] < 50]
print("\n8. Students with DL < 50:", q8[['Name', 'DL']])

# 9. Show students who scored more than 65 in NLP
q9 = df[df['NLP'] > 65]
print("\n9. Students with NLP > 65:", q9[['Name', 'NLP']])

# 10. Display students whose Total marks are less than 400
q10 = df[df['Total'] < 400]
print("\n10. Students with Total < 400:", q10[['Name', 'Total']])

# 11. Show students who scored more than 70 in Python and NumPy
q11 = df[(df['Python'] > 70) & (df['NumPy'] > 70)]
print("\n11. Students with Python > 70 AND NumPy > 70:", q11[['Name', 'Python', 'NumPy']])

# 12. Display students whose Pandas marks are below 60
q12 = df[df['Pandas'] < 60]
print("\n12. Students with Pandas < 60:", q12[['Name', 'Pandas']])

# 13. Find students with Grade B
q13 = df[df['Grade'] == 'B']
print("\n13. Students with Grade B:", q13)

# 14. Show students who scored above 85 in ML
q14 = df[df['ML'] > 85]
print("\n14. Students with ML > 85:", q14[['Name', 'ML']])

# 15. Display students who scored less than 55 in Streamlit
q15 = df[df['Streamlit'] < 55]
print("\n15. Students with Streamlit < 55:", q15[['Name', 'Streamlit']])

# 16. Show students whose Python marks are between 60 and 90
q16 = df[(df['Python'] >= 60) & (df['Python'] <= 90)]
print("\n16. Students with Python between 60-90:", q16[['Name', 'Python']])

# 17. Find students who scored above 70 in Pandas and NLP
q17 = df[(df['Pandas'] > 70) & (df['NLP'] > 70)]
print("\n17. Students with Pandas > 70 AND NLP > 70:", q17[['Name', 'Pandas', 'NLP']])

# 18. Display students whose DL marks are greater than 60
q18 = df[df['DL'] > 60]
print("\n18. Students with DL > 60:", q18[['Name', 'DL']])

# 19. Show students with Total marks between 400 and 500
q19 = df[(df['Total'] >= 400) & (df['Total'] <= 500)]
print("\n19. Students with Total between 400-500:", q19[['Name', 'Total']])

# 20. Display students who scored less than 65 in ML
q20 = df[df['ML'] < 65]
print("\n20. Students with ML < 65:", q20[['Name', 'ML']])

# 21. Show students who scored above 75 in NumPy
q21 = df[df['NumPy'] > 75]
print("\n21. Students with NumPy > 75:", q21[['Name', 'NumPy']])

# 22. Find students whose NLP marks are less than 50
q22 = df[df['NLP'] < 50]
print("\n22. Students with NLP < 50:", q22[['Name', 'NLP']])

# 23. Display students who scored more than 80 in Streamlit
q23 = df[df['Streamlit'] > 80]
print("\n23. Students with Streamlit > 80:", q23[['Name', 'Streamlit']])

# 24. Show students with Grade C
q24 = df[df['Grade'] == 'C']
print("\n24. Students with Grade C:", q24)

# 25. Display students who scored exactly 100 in Python
q25 = df[df['Python'] == 100]
print("\n25. Students with Python = 100:", q25[['Name', 'Python']])

# 26. Students with Python > 70 AND Pandas > 65
q26 = df[(df['Python'] > 70) & (df['Pandas'] > 65)]
print("\n26. Students with Python > 70 AND Pandas > 65:", q26[['Name', 'Python', 'Pandas']])

# 27. ML < 60 OR DL < 50
q27 = df[(df['ML'] < 60) | (df['DL'] < 50)]
print("\n27. Students with ML < 60 OR DL < 50:", q27[['Name', 'ML', 'DL']])

# 28. Grade A AND NLP > 60
q28 = df[(df['Grade'] == 'A') & (df['NLP'] > 60)]
print("\n28. Grade A and NLP > 60:", q28[['Name', 'Grade', 'NLP']])

# 29. Total > 500 AND Streamlit < 60
q29 = df[(df['Total'] > 500) & (df['Streamlit'] < 60)]
print("\n29. Total > 500 and Streamlit < 60:", q29[['Name', 'Total', 'Streamlit']])

# 30. Python, NumPy, Pandas all > 75
q30 = df[(df['Python'] > 75) & (df['NumPy'] > 75) & (df['Pandas'] > 75)]
print("\n30. Python, NumPy, Pandas all > 75:", q30[['Name', 'Python', 'NumPy', 'Pandas']])

# 31. Python < 50 AND NumPy < 50
q31 = df[(df['Python'] < 50) & (df['NumPy'] < 50)]
print("\n31. Python and NumPy both < 50:", q31[['Name', 'Python', 'NumPy']])

# 32. ML > 60 AND DL > 60
q32 = df[(df['ML'] > 60) & (df['DL'] > 60)]
print("\n32. ML and DL both > 60:", q32[['Name', 'ML', 'DL']])

# 33. Python > 80 BUT NLP < 60
q33 = df[(df['Python'] > 80) & (df['NLP'] < 60)]
print("\n33. Python > 80 but NLP < 60:", q33[['Name', 'Python', 'NLP']])

# 34. Total < 450 AND Grade B
q34 = df[(df['Total'] < 450) & (df['Grade'] == 'B')]
print("\n34. Total < 450 and Grade B:", q34[['Name', 'Total', 'Grade']])

# 35. Pandas > 70 OR NLP > 70
q35 = df[(df['Pandas'] > 70) | (df['NLP'] > 70)]
print("\n35. Pandas > 70 or NLP > 70:", q35[['Name', 'Pandas', 'NLP']])

# 36. Python, NumPy, Pandas all < 60
q36 = df[(df['Python'] < 60) & (df['NumPy'] < 60) & (df['Pandas'] < 60)]
print("\n36. All three < 60:", q36[['Name', 'Python', 'NumPy', 'Pandas']])

# 37. ML > 65 AND NLP > 65
q37 = df[(df['ML'] > 65) & (df['NLP'] > 65)]
print("\n37. ML and NLP both > 65:", q37[['Name', 'ML', 'NLP']])

# 38. Grade A BUT DL < 55
q38 = df[(df['Grade'] == 'A') & (df['DL'] < 55)]
print("\n38. Grade A but DL < 55:", q38[['Name', 'Grade', 'DL']])

# 39. Streamlit > 70 AND Pandas > 70
q39 = df[(df['Streamlit'] > 70) & (df['Pandas'] > 70)]
print("\n39. Streamlit and Pandas both > 70:", q39[['Name', 'Streamlit', 'Pandas']])

# 40. Less than 50 in at least one subject
subjects = ['Python', 'NumPy', 'Pandas', 'Streamlit', 'ML', 'DL', 'NLP']
q40 = df[df[subjects].lt(50).any(axis=1)]
print("\n40. Students with <50 in any subject:", q40[['Name'] + subjects])

# 41. Above 90 in any one subject
q41 = df[df[subjects].gt(90).any(axis=1)]
print("\n41. Students with >90 in any subject:", q41[['Name'] + subjects])

# 42. Total between 480 and 520
q42 = df[(df['Total'] >= 480) & (df['Total'] <= 520)]
print("\n42. Total between 480-520:", q42[['Name', 'Total']])

# 43. Python > 60 AND NumPy < 60
q43 = df[(df['Python'] > 60) & (df['NumPy'] < 60)]
print("\n43. Python > 60 but NumPy < 60:", q43[['Name', 'Python', 'NumPy']])

# 44. Grade B AND ML > 70
q44 = df[(df['Grade'] == 'B') & (df['ML'] > 70)]
print("\n44. Grade B and ML > 70:", q44[['Name', 'Grade', 'ML']])

# 45. NLP > DL
q45 = df[df['NLP'] > df['DL']]
print("\n45. NLP > DL:", q45[['Name', 'NLP', 'DL']])

# 46. Python, NumPy, Pandas all > 70
q46 = df[(df['Python'] > 70) & (df['NumPy'] > 70) & (df['Pandas'] > 70)]
print("\n46. All three > 70:", q46[['Name', 'Python', 'NumPy', 'Pandas']])

# 47. Python + NumPy + Pandas > 200
q47 = df[(df['Python'] + df['NumPy'] + df['Pandas']) > 200]
print("\n47. Sum of Python+NumPy+Pandas > 200:", q47[['Name', 'Python', 'NumPy', 'Pandas']])

# 48. Maximum marks in ML
max_ml = df['ML'].max()
q48 = df[df['ML'] == max_ml]
print(f"\n48. Students with max ML marks ({max_ml}):", q48[['Name', 'ML']])

# 49. Minimum marks in DL
min_dl = df['DL'].min()
q49 = df[df['DL'] == min_dl]
print(f"\n49. Students with min DL marks ({min_dl}):", q49[['Name', 'DL']])

# 50. Total marks above dataset average
avg_total = df['Total'].mean()
q50 = df[df['Total'] > avg_total]
print(f"\n50. Students with Total > average ({avg_total:.2f}):", q50[['Name', 'Total']])
# Out:
#   File "/tmp/ipykernel_1947/3713457812.py", line 1
#     vimport pandas as pd
#             ^
# SyntaxError: invalid syntax
